# %% [markdown]
# # Welcome to Crypto Advisor!!

# %% [markdown]
# #### Our aim here is to see how well your investment will perform should you invest in the top 3 cryptocurrencies in the market!
# ####

# %%
welcome_name = input("Welcome to crypto planner, what's your name?")
print(f"Hello, {welcome_name}")
# Out:
# Welcome to crypto planner, what's your name? Mark
# Hello, Mark

# %%
investment = 0
while investment < 5000:
    try:
        investment = int(input("How much are you thinking of investing?"))
        if investment < 5000:
            print("I'm sorry you don't have enough to get started, our minimum requirement is $5,000")
        elif investment >= 5000:
            print("Sounds good")
    except:
        investment = int(input("You dont put a number, please put a number"))
        print("Sounds good")
# Out:
# How much are you thinking of investing? 9250
# Sounds good

# %%
coin_prompt = ''
output = 0
output_2 = 0
output_3 = 0
while coin_prompt not in ['bitcoin','Bitcoin', 'BTC','ethereum', 'Ethereum', 'ETH','Cardano', 'cardano', 'ADA']:
    coin_prompt = input("Great, which cryptocurrency would you like to invest in?")
    try:
        if coin_prompt in ['bitcoin','Bitcoin', 'BTC']:
            output = input("Awesome! how much are you looking to invest in Bitcoin?")
            print(output)
        elif coin_prompt in ['ethereum', 'Ethereum', 'ETH']:
            output_2 = input("Awesome! how much are you looking to invest in Ethereum?")
            print(output_2)
        elif coin_prompt in ['Cardano', 'cardano', 'ADA']:
            output_3 = input("Awesome! how much are you looking to invest in Cardano?")
            print(output_3)
        else: 
            print("please go away")
    except:
        print('Choose the currency again:')
# Out:
# Great, which cryptocurrency would you like to invest in? ETH
# Awesome! how much are you looking to invest in Ethereum? 4250
# 4250

# %%
value = int(output) | int(output_2) | int(output_3)

# %%
if value == investment: 
    print("Let's see how your savings will perform")
elif value < investment: 
    remainder_prompt = int((investment) - int(value))
    answer = str(input(f"You'll have a remainder of {remainder_prompt}, are you think of investing this in another coin? Y/N"))
else:
    print(f"The maximum you can invest is {investment}, let's see how this will perform")
# Out:
# You'll have a remainder of 5000, are you think of investing this in another coin? Y/N N

# %%
if answer == 'Y':
    select_coin = input("Of which coin?")
    remainder_value = print(f"Okay, {remainder_prompt} has been put into {select_coin}.")
else:
    answer == 'N'
    print(f"No worries, let's move on.")

#total invested amt in code below

if answer == 'N':
    invested_amt = value
else:
    invested_amt = investment
# Out:
# No worries, let's move on.

# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv
from MCForecastTools import MCSimulation
import cryptocompare as cryptoapi 

# %matplotlib inline

# %%
btc_url = "https://min-api.cryptocompare.com/data/v2/histoday?fsym=BTC&tsym=USD&limit=1095"
eth_url = "https://min-api.cryptocompare.com/data/v2/histoday?fsym=ETH&tsym=USD&limit=1095"
ada_url = "https://min-api.cryptocompare.com/data/v2/histoday?fsym=ADA&tsym=USD&limit=1095"
btc_data = requests.get(btc_url).json()
eth_data = requests.get(eth_url).json() 
ada_data = requests.get(ada_url).json()

# %%
import json

# %%
btc_s0= []
date = []
for price in range(0,len(btc_data['Data']['Data'])):
    temp= btc_data['Data']['Data'][price]['close']
    temp_date = btc_data['Data']['Data'][price]['time']
    btc_s0.append(temp)
    date.append(temp_date)

# %%
eth_s0= []
date = []
for price in range(0,len(eth_data['Data']['Data'])):
    temp= eth_data['Data']['Data'][price]['close']
    temp_date = eth_data['Data']['Data'][price]['time']
    eth_s0.append(temp)
    date.append(temp_date)

# %%
ada_s0= []
date = []
for price in range(0,len(ada_data['Data']['Data'])):
    temp= ada_data['Data']['Data'][price]['close']
    temp_date = ada_data['Data']['Data'][price]['time']
    ada_s0.append(temp)
    date.append(temp_date)

# %%
import datetime

# %%
conv_date = []
for date_converted in date:
    date_con = datetime.datetime.fromtimestamp(
        int(date_converted)
    ).strftime('%Y-%m-%d %H:%M:%S')
    print(date_con)
    conv_date.append(date_con)
# Out:
# 2018-11-30 11:00:00
# 2018-12-01 11:00:00
# 2018-12-02 11:00:00
# 2018-12-03 11:00:00
# 2018-12-04 11:00:00
# 2018-12-05 11:00:00
# 2018-12-06 11:00:00
# 2018-12-07 11:00:00
# 2018-12-08 11:00:00
# 2018-12-09 11:00:00
# 2018-12-10 11:00:00
# 2018-12-11 11:00:00
# 2018-12-12 11:00:00
# 2018-12-13 11:00:00
# 2018-12-14 11:00:00
# 2018-12-15 11:00:00
# 2018-12-16 11:00:00
# 2018-12-17 11:00:00
# 2018-12-18 11:00:00
# 2018-12-19 11:00:00
# 2018-12-20 11:00:00
# 2018-12-21 11:00:00
# 2018-12-22 11:00:00
# 2018-12-23 11:00:00
# 2018-12-24 11:00:00
# 2018-12-25 11:00:00
# 2018-12-26 11:00:00
# 2018-12-27 11:00:00
# 2018-12-28 11:00:00
# 2018-12-29 11:00:00
# 2018-12-30 11:00:00
# 2018-12-31 11:00:00
# 2019-01-01 11:00:00
# 2019-01-02 11:00:00
# 2019-01-03 11:00:00
# 2019-01-04 11:00:00
# 2019-01-05 11:00:00
# 2019-01-06 11:00:00
# 2019-01-07 11:00:00
# 2019-01-08 11:00:00
# 2019-01-09 11:00:00
# 2019-01-10 11:00:00
# 2019-01-11 11:00:00
# 2019-01-12 11:00:00
# 2019-01-13 11:00:00
# 2019-01-14 11:00:00
# 2019-01-15 11:00:00
# 2019-01-16 11:00:00
# 2019-01-17 11:00:00
# 2019-01-18 11:00:00
# 2019-01-19 11:00:00
# 2019-01-20 11:00:00
# 2019-01-21 11:00:00
# 2019-01-22 11:00:00
# 2019-01-23 11:00:00
# 2019-01-24 11:00:00
# 2019-01-25 11:00:00
# 2019-01-26 11:00:00
# 2019-01-27 11:00:00
# 2019-01-28 11:00:00
# 2019-01-29 11:00:00
# 2019-01-30 11:00:00
# 2019-01-31 11:00:00
# 2019-02-01 11:00:00
# 2019-02-02 11:00:00
# 2019-02-03 11:00:00
# 2019-02-04 11:00:00
# 2019-02-05 11:00:00
# 2019-02-06 11:00:00
# 2019-02-07 11:00:00
# 2019-02-08 11:00:00
# 2019-02-09 11:00:00
# 2019-02-10 11:00:00
# 2019-02-11 11:00:00
# 2019-02-12 11:00:00
# 2019-02-13 11:00:00
# 2019-02-14 11:00:00
# 2019-02-15 11:00:00
# 2019-02-16 11:00:00
# 2019-02-17 11:00:00
# 2019-02-18 11:00:00
# 2019-02-19 11:00:00
# 2019-02-20 11:00:00
# 2019-06-04 10:00:00
# 2019-06-05 10:00:00
# 2019-06-06 10:00:00
# 2019-06-07 10:00:00
# 2019-06-08 10:00:00
# 2019-06-09 10:00:00
# 2019-06-10 10:00:00
# 2019-06-11 10:00:00
# 2019-06-12 10:00:00
# 2019-06-13 10:00:00
# 2019-06-14 10:00:00
# 2019-06-15 10:00:00
# 2019-06-16 10:00:00
# 2019-06-17 10:00:00
# 2019-06-18 10:00:00
# 2019-06-19 10:00:00
# 2019-06-20 10:00:00
# 2019-06-21 10:00:00
# 2019-06-22 10:00:00
# 2019-06-23 10:00:00
# 2019-06-24 10:00:00
# 2019-06-25 10:00:00
# 2019-06-26 10:00:00
# 2019-06-27 10:00:00
# 2019-06-28 10:00:00
# 2019-06-29 10:00:00
# 2019-06-30 10:00:00
# 2019-07-01 10:00:00
# 2019-07-02 10:00:00
# 2019-07-03 10:00:00
# 2019-07-04 10:00:00
# 2019-07-05 10:00:00
# 2019-07-06 10:00:00
# 2019-07-07 10:00:00
# 2019-07-08 10:00:00
# 2019-07-09 10:00:00
# 2019-07-10 10:00:00
# 2019-07-11 10:00:00
# 2019-07-12 10:00:00
# 2019-07-13 10:00:00
# 2019-07-14 10:00:00
# 2019-07-15 10:00:00
# 2019-07-16 10:00:00
# 2019-07-17 10:00:00
# 2019-07-18 10:00:00
# 2019-07-19 10:00:00
# 2019-07-20 10:00:00
# 2019-07-21 10:00:00
# 2019-07-22 10:00:00
# 2019-07-23 10:00:00
# 2019-07-24 10:00:00
# 2019-07-25 10:00:00
# 2019-07-26 10:00:00
# 2019-07-27 10:00:00
# 2019-07-28 10:00:00
# 2019-07-29 10:00:00
# 2019-07-30 10:00:00
# 2019-07-31 10:00:00
# 2019-08-01 10:00:00
# 2019-08-02 10:00:00
# 2019-08-03 10:00:00
# 2019-08-04 10:00:00
# 2019-08-05 10:00:00
# 2019-08-06 10:00:00
# 2019-08-07 10:00:00
# 2019-08-08 10:00:00
# 2019-08-09 10:00:00
# 2019-08-10 10:00:00
# 2019-08-11 10:00:00
# 2019-08-12 10:00:00
# 2019-08-13 10:00:00
# 2019-08-14 10:00:00
# 2019-08-15 10:00:00
# 2019-08-16 10:00:00
# 2019-08-17 10:00:00
# 2019-08-18 10:00:00
# 2019-08-19 10:00:00
# 2019-08-20 10:00:00
# 2019-08-21 10:00:00
# 2019-08-22 10:00:00
# 2019-08-23 10:00:00
# 2019-08-24 10:00:00
# 2019-08-25 10:00:00
# 2019-08-26 10:00:00
# 2019-08-27 10:00:00
# 2019-08-28 10:00:00
# 2019-08-29 10:00:00
# 2019-08-30 10:00:00
# 2019-08-31 10:00:00
# 2019-09-01 10:00:00
# 2019-09-02 10:00:00
# 2019-09-03 10:00:00
# 2019-09-04 10:00:00
# 2019-09-05 10:00:00
# 2019-09-06 10:00:00
# 2019-09-07 10:00:00
# 2019-09-08 10:00:00
# 2019-09-09 10:00:00
# 2019-09-10 10:00:00
# 2019-09-11 10:00:00
# 2019-09-12 10:00:00
# 2019-09-13 10:00:00
# 2019-09-14 10:00:00
# 2019-09-15 10:00:00
# 2021-09-11 10:00:00
# 2021-09-12 10:00:00
# 2021-09-13 10:00:00
# 2021-09-14 10:00:00
# 2021-09-15 10:00:00
# 2021-09-16 10:00:00
# 2021-09-17 10:00:00
# 2021-09-18 10:00:00
# 2021-09-19 10:00:00
# 2021-09-20 10:00:00
# 2021-09-21 10:00:00
# 2021-09-22 10:00:00
# 2021-09-23 10:00:00
# 2021-09-24 10:00:00
# 2021-09-25 10:00:00
# 2021-09-26 10:00:00
# 2021-09-27 10:00:00
# 2021-09-28 10:00:00
# 2021-09-29 10:00:00
# 2021-09-30 10:00:00
# 2021-10-01 10:00:00
# 2021-10-02 10:00:00
# 2021-10-03 11:00:00
# 2021-10-04 11:00:00
# 2021-10-05 11:00:00
# 2021-10-06 11:00:00
# 2021-10-07 11:00:00
# 2021-10-08 11:00:00
# 2021-10-09 11:00:00
# 2021-10-10 11:00:00
# 2021-10-11 11:00:00
# 2021-10-12 11:00:00
# 2021-10-13 11:00:00
# 2021-10-14 11:00:00
# 2021-10-15 11:00:00
# 2021-10-16 11:00:00
# 2021-10-17 11:00:00
# 2021-10-18 11:00:00
# 2021-10-19 11:00:00
# 2021-10-20 11:00:00
# 2021-10-21 11:00:00
# 2021-10-22 11:00:00
# 2021-10-23 11:00:00
# 2021-10-24 11:00:00
# 2021-10-25 11:00:00
# 2021-10-26 11:00:00
# 2021-10-27 11:00:00
# 2021-10-28 11:00:00
# 2021-10-29 11:00:00
# 2021-10-30 11:00:00
# 2021-10-31 11:00:00
# 2021-11-01 11:00:00
# 2021-11-02 11:00:00
# 2021-11-03 11:00:00
# 2021-11-04 11:00:00
# 2021-11-05 11:00:00
# 2021-11-06 11:00:00
# 2021-11-07 11:00:00
# 2021-11-08 11:00:00
# 2021-11-09 11:00:00
# 2021-11-10 11:00:00
# 2021-11-11 11:00:00
# 2021-11-12 11:00:00
# 2021-11-13 11:00:00
# 2021-11-14 11:00:00
# 2021-11-15 11:00:00
# 2021-11-16 11:00:00
# 2021-11-17 11:00:00
# 2021-11-18 11:00:00
# 2021-11-19 11:00:00
# 2021-11-20 11:00:00
# 2021-11-21 11:00:00
# 2021-11-22 11:00:00
# 2021-11-23 11:00:00
# 2021-11-24 11:00:00
# 2021-11-25 11:00:00
# 2021-11-26 11:00:00
# 2021-11-27 11:00:00
# 2021-11-28 11:00:00
# 2021-11-29 11:00:00

# %%
list_name_date = conv_date
df_date = pd.DataFrame (list_name_date, columns = ['date'])

# %%
list_name_ada = ada_s0
df_ada = pd.DataFrame (list_name_ada, columns = ['ADA'])

# %%
list_name_eth = eth_s0
df_eth = pd.DataFrame (list_name_eth, columns = ['ETH'])

# %%
list_name_btc = btc_s0
df_btc = pd.DataFrame (list_name_btc, columns = ['BTC'])

# %%
dataset = pd.concat([df_date, df_ada, df_eth, df_btc], axis=1)

# %%
dataset = dataset.set_index('date')

# %% [markdown]
# Gathering Data (Benchmark)

# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
data = Path("Historical_data.csv")

# %%
benchmark_df = pd.read_csv(data, index_col = 'Date', infer_datetime_format=True, parse_dates=True)

# %%
benchmark_df = benchmark_df.sort_values(['Date'], ascending = True)

# %%
a = benchmark_df['Close/Last']

# %%
CIX100_prices = benchmark_df.drop(columns=['Volume', 'Open', 'High', 'Low'])
CIX100_std = CIX100_prices.std
CIX100_std()
# Out:
# Close/Last    2.08323
# dtype: float64

# %%
CIX100_sharpe = (CIX100_prices.mean() * 252) / (CIX100_std() * np.sqrt(252))
CIX100_sharpe
# Out:
# Close/Last    18.059808
# dtype: float64

# %%
t1 = dataset[["BTC","ETH","ADA"]]

# %%
tpct = dataset[["BTC","ETH","ADA"]].pct_change()
tmean = dataset[["BTC","ETH","ADA"]].mean
tstd = dataset[["BTC","ETH","ADA"]].std

# %%
from MCForecastTools import MCSimulation

# %%
CIX100_prices.rename(columns={'Close/Last':"Close"})
CIX100_prices.columns = pd.MultiIndex.from_product([CIX100_prices.columns,['close']])

# %%
dataset.columns = pd.MultiIndex.from_product([dataset.columns,['close']])

# %%
num_sims = 1000

MC_3_COINS = MCSimulation(
    portfolio_data = dataset,
    num_simulation = num_sims,
    num_trading_days = 252*5
)

# %%
MC_3_COINS.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# C:\Users\markp\Fintech\Project\MCForecastTools.py:117: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   portfolio_cumulative_returns[n] = (1 + sim_df.fillna(0)).cumprod()
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# Running Monte Carlo simulation number 500.
# Running Monte Carlo simulation number 510.
# Running Monte Carlo simulation number 520.
# Running Monte Carlo simulation number 530.
# Running Monte Carlo simulation number 540.
# Running Monte Carlo simulation number 550.
# Running Monte Carlo simulation number 560.
# Running Monte Carlo simulation number 570.
# Running Monte Carlo simulation number 580.
# Running Monte Carlo simulation number 590.
# Running Monte Carlo simulation number 600.
# Running Monte Carlo simulation number 610.
# Running Monte Carlo simulation number 620.
# Running Monte Carlo simulation number 630.
# Running Monte Carlo simulation number 640.
# Running Monte Carlo simulation number 650.
# Running Monte Carlo simulation number 660.
# Running Monte Carlo simulation number 670.
# Running Monte Carlo simulation number 680.
# Running Monte Carlo simulation number 690.
# Running Monte Carlo simulation number 700.
# Running Monte Carlo simulation number 710.
# Running Monte Carlo simulation number 720.
# Running Monte Carlo simulation number 730.
# Running Monte Carlo simulation number 740.
# Running Monte Carlo simulation number 750.
# Running Monte Carlo simulation number 760.
# Running Monte Carlo simulation number 770.
# Running Monte Carlo simulation number 780.
# Running Monte Carlo simulation number 790.
# Running Monte Carlo simulation number 800.
# Running Monte Carlo simulation number 810.
# Running Monte Carlo simulation number 820.
# Running Monte Carlo simulation number 830.
# Running Monte Carlo simulation number 840.
# Running Monte Carlo simulation number 850.
# Running Monte Carlo simulation number 860.
# Running Monte Carlo simulation number 870.
# Running Monte Carlo simulation number 880.
# Running Monte Carlo simulation number 890.
# Running Monte Carlo simulation number 900.
# Running Monte Carlo simulation number 910.
# Running Monte Carlo simulation number 920.
# Running Monte Carlo simulation number 930.
# Running Monte Carlo simulation number 940.
# Running Monte Carlo simulation number 950.
# Running Monte Carlo simulation number 960.
# Running Monte Carlo simulation number 970.
# Running Monte Carlo simulation number 980.
# Running Monte Carlo simulation number 990.
#              0           1          2           3           4          5    \
# 0       1.000000    1.000000   1.000000    1.000000    1.000000   1.000000
# 1       1.015339    1.003414   1.002960    1.016979    1.012232   1.010197
# 2       1.016599    1.008667   1.052524    0.998073    1.027271   1.005591
# 3       1.035314    1.027796   1.122376    1.013834    1.056059   1.002289
# 4       1.114626    1.029042   1.161309    1.013449    1.065787   0.954342
# ...          ...         ...        ...         ...         ...        ...
# 1256  458.709631  696.331258  86.252400  188.870058  262.734646  81.584452
# 1257  475.899106  708.459034  82.804188  190.156772  266.002778  84.305817
# 1258  471.332300  715.737156  78.547778  186.956305  266.662750  83.706549
# 1259  478.372540  706.155074  79.233096  190.871562  267.904281  82.091918
# 1260  494.442368  713.712519  79.514500  192.264054  266.611058  86.358629
#
#             6           7           8          9    ...         990  \
# 0      1.000000    1.000000    1.000000   1.000000  ...    1.000000
# 1      1.018654    1.002212    1.025642   1.019347  ...    1.016498
# 2      1.011061    1.022251    1.036115   0.987655  ...    1.084557
# 3      1.019349    0.995421    1.013355   0.960718  ...    1.061724
# 4      1.022736    1.004695    1.037097   0.909799  ...    1.114131
# ...         ...         ...         ...        ...  ...         ...
# 1256  47.269001  260.779931  349.107412  88.595573  ...  253.052480
# 1257  49.507554  266.138973  350.674770  85.962867  ...  250.679880
# 1258  49.255804  262.432038  344.280195  86.666721  ...  236.730251
# 1259  49.737204  259.550749  333.250304  85.790160  ...  243.071108
# 1260  47.394630  247.751782  335.727653  83.166519  ...  251.793404
#
#             991         992        993        994         995         996  \
# 0      1.000000    1.000000   1.000000   1.000000    1.000000    1.000000
# 1      0.989045    1.042386   1.068530   1.023770    1.017229    0.980881
# 2      0.990578    1.059312   1.082144   0.985717    1.054613    0.966806
# 3      1.032363    1.116723   1.081173   1.030494    1.077073    1.003244
# 4      1.028905    1.187363   1.056523   1.031858    1.048664    0.957350
# ...         ...         ...        ...        ...         ...         ...
# 1256  53.683049  131.594682  66.838817  25.610110  103.301696  321.862427
# 1257  53.044135  135.517220  64.559344  24.892438  104.233958  307.443478
# 1258  53.795381  137.460050  61.838645  25.658672  100.260152  324.830439
# 1259  54.876069  136.837817  64.268720  26.416346   95.369288  328.556983
# 1260  56.254938  137.468621  66.522018  26.218335   95.538962  332.532944
#
#             997          998        999
# 0      1.000000     1.000000   1.000000
# 1      0.975590     0.986021   1.033152
# 2      0.975298     0.978326   1.002541
# 3      0.998126     0.947046   0.977670
# 4      1.046382     0.934050   1.018028
# ...         ...          ...        ...
# 1256  83.926058   974.192247  85.616426
# 1257  85.189712   952.134429  88.764509
# 1258  85.902079   991.839557  86.257764
# 1259  87.323962  1030.443218  89.438117
# 1260  90.803596  1004.225803  88.740696
#
# [1261 rows x 1000 columns]

# %%
MC_3_COINS.plot_simulation()
# Out:
# <AxesSubplot:title={'center':'1000 Simulations of Cumulative Portfolio Return Trajectories Over the Next 1260 Trading Days.'}>

# %%
btc_close_df =  pd.DataFrame(dataset['BTC','close'])
eth_close_df = pd.DataFrame(dataset['ETH','close'])
ada_close_df = pd.DataFrame(dataset['ADA','close'])

# %%
num_sims = 1000

MC_BTC = MCSimulation(
    portfolio_data = btc_close_df,
    num_simulation = num_sims,
    num_trading_days = 252*5
)

# %%
MC_BTC.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# C:\Users\markp\Fintech\Project\MCForecastTools.py:117: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   portfolio_cumulative_returns[n] = (1 + sim_df.fillna(0)).cumprod()
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# Running Monte Carlo simulation number 500.
# Running Monte Carlo simulation number 510.
# Running Monte Carlo simulation number 520.
# Running Monte Carlo simulation number 530.
# Running Monte Carlo simulation number 540.
# Running Monte Carlo simulation number 550.
# Running Monte Carlo simulation number 560.
# Running Monte Carlo simulation number 570.
# Running Monte Carlo simulation number 580.
# Running Monte Carlo simulation number 590.
# Running Monte Carlo simulation number 600.
# Running Monte Carlo simulation number 610.
# Running Monte Carlo simulation number 620.
# Running Monte Carlo simulation number 630.
# Running Monte Carlo simulation number 640.
# Running Monte Carlo simulation number 650.
# Running Monte Carlo simulation number 660.
# Running Monte Carlo simulation number 670.
# Running Monte Carlo simulation number 680.
# Running Monte Carlo simulation number 690.
# Running Monte Carlo simulation number 700.
# Running Monte Carlo simulation number 710.
# Running Monte Carlo simulation number 720.
# Running Monte Carlo simulation number 730.
# Running Monte Carlo simulation number 740.
# Running Monte Carlo simulation number 750.
# Running Monte Carlo simulation number 760.
# Running Monte Carlo simulation number 770.
# Running Monte Carlo simulation number 780.
# Running Monte Carlo simulation number 790.
# Running Monte Carlo simulation number 800.
# Running Monte Carlo simulation number 810.
# Running Monte Carlo simulation number 820.
# Running Monte Carlo simulation number 830.
# Running Monte Carlo simulation number 840.
# Running Monte Carlo simulation number 850.
# Running Monte Carlo simulation number 860.
# Running Monte Carlo simulation number 870.
# Running Monte Carlo simulation number 880.
# Running Monte Carlo simulation number 890.
# Running Monte Carlo simulation number 900.
# Running Monte Carlo simulation number 910.
# Running Monte Carlo simulation number 920.
# Running Monte Carlo simulation number 930.
# Running Monte Carlo simulation number 940.
# Running Monte Carlo simulation number 950.
# Running Monte Carlo simulation number 960.
# Running Monte Carlo simulation number 970.
# Running Monte Carlo simulation number 980.
# Running Monte Carlo simulation number 990.
#             0          1         2          3          4          5    \
# 0      1.000000   1.000000  1.000000   1.000000   1.000000   1.000000
# 1      1.017476   0.965733  0.982233   1.039573   1.073765   0.995288
# 2      1.043396   1.036982  1.067638   1.066704   1.112570   0.986746
# 3      1.058872   1.044000  1.020474   1.036027   1.100793   1.084759
# 4      1.033646   1.046061  1.057211   1.010871   1.036353   1.067865
# ...         ...        ...       ...        ...        ...        ...
# 1256  66.777040  30.052532  7.122693  82.543046  11.251015  23.139799
# 1257  65.751476  30.981303  7.413439  86.528929  11.603134  23.555207
# 1258  65.303160  30.656948  7.019766  85.303351  11.478355  23.758911
# 1259  65.171923  33.847645  7.479143  80.817354  10.991208  24.424225
# 1260  60.553781  33.677558  7.735737  79.646074  10.524234  23.748306
#
#             6          7         8          9    ...        990        991  \
# 0      1.000000   1.000000  1.000000   1.000000  ...   1.000000   1.000000
# 1      1.123824   1.057417  0.912644   1.006099  ...   0.960097   0.981817
# 2      1.060134   0.929889  0.860266   1.033348  ...   0.965850   0.961945
# 3      1.131608   0.943067  0.855244   1.095336  ...   0.962177   0.960224
# 4      1.169358   0.963354  0.838253   1.033620  ...   1.023234   0.906476
# ...         ...        ...       ...        ...  ...        ...        ...
# 1256  31.994279  74.013290  0.576028  81.227033  ...  42.542330  26.453078
# 1257  32.741780  75.625773  0.586118  81.675684  ...  43.288620  25.591796
# 1258  32.347905  73.175819  0.574835  79.354728  ...  42.426584  24.705168
# 1259  32.734289  72.611488  0.622486  75.839854  ...  38.954999  24.495206
# 1260  30.888370  67.855023  0.629500  75.458630  ...  40.174538  23.469741
#
#             992       993       994        995         996        997  \
# 0      1.000000  1.000000  1.000000   1.000000    1.000000   1.000000
# 1      1.026290  1.027487  1.035174   0.932670    0.974358   1.001588
# 2      1.056407  1.086109  0.975673   0.879528    1.012017   0.967767
# 3      1.110205  1.124634  0.944618   0.839734    1.061176   0.995525
# 4      1.158315  1.109911  0.920690   0.827684    1.030703   1.004413
# ...         ...       ...       ...        ...         ...        ...
# 1256  16.154225  9.138711  5.497411  45.189817  155.069833  93.640663
# 1257  16.102441  9.295878  5.652312  44.055901  149.484291  88.771571
# 1258  16.412474  9.722836  5.926590  44.232891  157.048421  88.066400
# 1259  17.423841  9.460122  5.869609  47.038063  161.567266  90.945794
# 1260  18.534705  9.480383  6.106367  47.000762  153.917238  89.960211
#
#             998       999
# 0      1.000000  1.000000
# 1      1.016093  0.946083
# 2      0.980498  0.982657
# 3      0.952659  1.071077
# 4      0.969639  1.131422
# ...         ...       ...
# 1256  31.298627  1.229422
# 1257  31.736408  1.221511
# 1258  32.129439  1.220192
# 1259  30.578857  1.277793
# 1260  31.380263  1.283984
#
# [1261 rows x 1000 columns]

# %%
MC_BTC.plot_simulation()
# Out:
# <AxesSubplot:title={'center':'1000 Simulations of Cumulative Portfolio Return Trajectories Over the Next 1260 Trading Days.'}>

# %%
num_sims = 1000

MC_ETH = MCSimulation(
    portfolio_data = eth_close_df,
    num_simulation = num_sims,
    num_trading_days = 252*5
)

# %%
MC_ETH.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# C:\Users\markp\Fintech\Project\MCForecastTools.py:117: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   portfolio_cumulative_returns[n] = (1 + sim_df.fillna(0)).cumprod()
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# Running Monte Carlo simulation number 500.
# Running Monte Carlo simulation number 510.
# Running Monte Carlo simulation number 520.
# Running Monte Carlo simulation number 530.
# Running Monte Carlo simulation number 540.
# Running Monte Carlo simulation number 550.
# Running Monte Carlo simulation number 560.
# Running Monte Carlo simulation number 570.
# Running Monte Carlo simulation number 580.
# Running Monte Carlo simulation number 590.
# Running Monte Carlo simulation number 600.
# Running Monte Carlo simulation number 610.
# Running Monte Carlo simulation number 620.
# Running Monte Carlo simulation number 630.
# Running Monte Carlo simulation number 640.
# Running Monte Carlo simulation number 650.
# Running Monte Carlo simulation number 660.
# Running Monte Carlo simulation number 670.
# Running Monte Carlo simulation number 680.
# Running Monte Carlo simulation number 690.
# Running Monte Carlo simulation number 700.
# Running Monte Carlo simulation number 710.
# Running Monte Carlo simulation number 720.
# Running Monte Carlo simulation number 730.
# Running Monte Carlo simulation number 740.
# Running Monte Carlo simulation number 750.
# Running Monte Carlo simulation number 760.
# Running Monte Carlo simulation number 770.
# Running Monte Carlo simulation number 780.
# Running Monte Carlo simulation number 790.
# Running Monte Carlo simulation number 800.
# Running Monte Carlo simulation number 810.
# Running Monte Carlo simulation number 820.
# Running Monte Carlo simulation number 830.
# Running Monte Carlo simulation number 840.
# Running Monte Carlo simulation number 850.
# Running Monte Carlo simulation number 860.
# Running Monte Carlo simulation number 870.
# Running Monte Carlo simulation number 880.
# Running Monte Carlo simulation number 890.
# Running Monte Carlo simulation number 900.
# Running Monte Carlo simulation number 910.
# Running Monte Carlo simulation number 920.
# Running Monte Carlo simulation number 930.
# Running Monte Carlo simulation number 940.
# Running Monte Carlo simulation number 950.
# Running Monte Carlo simulation number 960.
# Running Monte Carlo simulation number 970.
# Running Monte Carlo simulation number 980.
# Running Monte Carlo simulation number 990.
#            0           1         2           3          4          5    \
# 0     1.000000    1.000000  1.000000    1.000000   1.000000   1.000000
# 1     1.079393    0.969416  1.146718    1.007333   1.063518   1.028387
# 2     1.098170    0.935677  1.159758    1.037103   1.038850   1.032714
# 3     1.113649    1.044383  1.124556    1.077717   1.009252   1.057962
# 4     1.034508    0.941709  1.171006    1.058869   1.071350   1.066600
# ...        ...         ...       ...         ...        ...        ...
# 1256  7.563674  242.765838  7.339174  178.343976  22.004179  41.756300
# 1257  7.722699  233.477388  7.583265  172.554826  22.048360  43.179102
# 1258  7.168419  231.249431  7.541038  159.315967  21.251288  41.238718
# 1259  7.192823  207.474407  7.548659  157.308134  20.921784  42.296315
# 1260  6.913868  205.432174  7.852967  160.174282  20.807559  42.416709
#
#             6           7          8           9    ...        990  \
# 0      1.000000    1.000000   1.000000    1.000000  ...   1.000000
# 1      0.957128    0.918357   1.059276    1.055912  ...   0.943779
# 2      0.966578    1.015819   1.037608    1.037158  ...   0.898584
# 3      1.039917    1.052492   1.111613    0.928871  ...   0.849101
# 4      1.027461    1.147915   1.080510    0.993997  ...   0.851048
# ...         ...         ...        ...         ...  ...        ...
# 1256  27.874823  156.364682  32.118598  277.167245  ...  23.150213
# 1257  27.868084  167.103166  32.208968  291.408699  ...  24.596074
# 1258  31.189054  158.099497  34.373242  288.958270  ...  23.244923
# 1259  32.694444  153.999643  36.491905  298.280425  ...  25.127364
# 1260  31.548265  160.615476  33.486820  291.041826  ...  25.152857
#
#              991        992        993         994         995        996  \
# 0       1.000000   1.000000   1.000000    1.000000    1.000000   1.000000
# 1       1.034118   0.942195   0.944527    1.025086    1.074254   0.987404
# 2       0.911712   0.827122   0.978803    1.072887    1.042460   1.049234
# 1       0.983076   1.023552   1.139088  0.914698   1.093966    0.974969
# 2       0.985109   1.016159   1.203559  0.922973   1.165577    1.057049
# 3       0.971641   0.998154   1.360696  0.960074   1.031496    1.074005
# 4       0.939115   1.029547   1.281848  0.953044   1.122978    1.118281
# ...          ...        ...        ...       ...        ...         ...
# 1256  877.840373  60.015942  30.549207  1.443486  82.623016  358.802500
# 1257  895.500349  58.763312  33.799488  1.483545  80.787177  381.830285
# 1258  843.449432  58.015341  33.754490  1.441283  84.933370  375.411661
# 1259  897.492620  55.622741  32.353621  1.327835  81.799571  395.435209
# 1260  935.465778  57.676432  32.836980  1.360449  85.403185  384.974341
#
#             998        999
# 0      1.000000   1.000000
# 1      0.953449   0.995305
# 2      0.952409   1.052606
# 3      0.977202   1.125159
# 4      0.921501   1.068458
# ...         ...        ...
# 1256  33.867433  22.041587
# 1257  36.432256  23.710478
# 1258  37.987763  23.354532
# 1259  37.538524  25.395266
# 1260  38.251713  26.822782
#
# [1261 rows x 1000 columns]

# %%
MC_ADA.plot_simulation()
# Out:
# <AxesSubplot:title={'center':'1000 Simulations of Cumulative Portfolio Return Trajectories Over the Next 1260 Trading Days.'}>

# %%
MC_ADA.summarize_cumulative_return()
# Out:
# count            1000.000000
# mean              734.124321
# std              2814.402698
# min                 0.079273
# 25%                19.057078
# 50%                77.371208
# 75%               345.815744
# max             41188.251519
# 95% CI Lower        1.244931
# 95% CI Upper     6393.896520
# Name: 1260, dtype: float64

# %%
az = {
    "mean": list(MC_ADA.simulated_return.mean(axis=1)),
    "median": list(MC_ADA.simulated_return.median(axis=1)),
    "min": list(MC_ADA.simulated_return.min(axis=1)),
    "max": list(MC_ADA.simulated_return.max(axis=1))
}
bz = {
    "mean": list(MC_ETH.simulated_return.mean(axis=1)),
    "median": list(MC_ETH.simulated_return.median(axis=1)),
    "min": list(MC_ETH.simulated_return.min(axis=1)),
    "max": list(MC_ETH.simulated_return.max(axis=1))
}
cz = {
    "mean": list(MC_BTC.simulated_return.mean(axis=1)),
    "median": list(MC_BTC.simulated_return.median(axis=1)),
    "min": list(MC_BTC.simulated_return.min(axis=1)),
    "max": list(MC_BTC.simulated_return.max(axis=1))
}

bitcoin_df = pd.DataFrame(cz)
eth_df = pd.DataFrame(bz)
ada_df = pd.DataFrame(az)

# %%
num_sims = 1000

MC_CRYPTO = MCSimulation(
    portfolio_data = CIX100_prices,
    num_simulation = num_sims,
    num_trading_days = 252*5
)
MC_CRYPTO.calc_cumulative_return()

sim_returns_data = {
    "mean": list(MC_CRYPTO.simulated_return.mean(axis=1)),
    "median": list(MC_CRYPTO.simulated_return.median(axis=1)),
    "min": list(MC_CRYPTO.simulated_return.min(axis=1)),
    "max": list(MC_CRYPTO.simulated_return.max(axis=1))
}

df_simulated_returns = pd.DataFrame(sim_returns_data)
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# C:\Users\markp\Fintech\Project\MCForecastTools.py:117: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   portfolio_cumulative_returns[n] = (1 + sim_df.fillna(0)).cumprod()
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# Running Monte Carlo simulation number 500.
# Running Monte Carlo simulation number 510.
# Running Monte Carlo simulation number 520.
# Running Monte Carlo simulation number 530.
# Running Monte Carlo simulation number 540.
# Running Monte Carlo simulation number 550.
# Running Monte Carlo simulation number 560.
# Running Monte Carlo simulation number 570.
# Running Monte Carlo simulation number 580.
# Running Monte Carlo simulation number 590.
# Running Monte Carlo simulation number 600.
# Running Monte Carlo simulation number 610.
# Running Monte Carlo simulation number 620.
# Running Monte Carlo simulation number 630.
# Running Monte Carlo simulation number 640.
# Running Monte Carlo simulation number 650.
# Running Monte Carlo simulation number 660.
# Running Monte Carlo simulation number 670.
# Running Monte Carlo simulation number 680.
# Running Monte Carlo simulation number 690.
# Running Monte Carlo simulation number 700.
# Running Monte Carlo simulation number 710.
# Running Monte Carlo simulation number 720.
# Running Monte Carlo simulation number 730.
# Running Monte Carlo simulation number 740.
# Running Monte Carlo simulation number 750.
# Running Monte Carlo simulation number 760.
# Running Monte Carlo simulation number 770.
# Running Monte Carlo simulation number 780.
# Running Monte Carlo simulation number 790.
# Running Monte Carlo simulation number 800.
# Running Monte Carlo simulation number 810.
# Running Monte Carlo simulation number 820.
# Running Monte Carlo simulation number 830.
# Running Monte Carlo simulation number 840.
# Running Monte Carlo simulation number 850.
# Running Monte Carlo simulation number 860.
# Running Monte Carlo simulation number 870.
# Running Monte Carlo simulation number 880.
# Running Monte Carlo simulation number 890.
# Running Monte Carlo simulation number 900.
# Running Monte Carlo simulation number 910.
# Running Monte Carlo simulation number 920.
# Running Monte Carlo simulation number 930.
# Running Monte Carlo simulation number 940.
# Running Monte Carlo simulation number 950.
# Running Monte Carlo simulation number 960.
# Running Monte Carlo simulation number 970.
# Running Monte Carlo simulation number 980.
# Running Monte Carlo simulation number 990.

# %%
tbl = MC_CRYPTO.summarize_cumulative_return()
ci_lower2 = round(tbl[8]*5000,2)
ci_upper2 = round(tbl[9]*5000,2)

if coin_prompt == ['bitcoin','Bitcoin', 'BTC']:
    
    investment_1 = MC_BTC.summarize_cumulative_return()
    ci_lower = round(investment_1[8]*(invested_amt),2)
    ci_upper = round(investment_1[9]*(invested_amt),2)
    
elif coin_prompt ==['ethereum', 'ETH', 'Ethereum']:
                        
    
    investment_1 = MC_ETH.summarize_cumulative_return()
    ci_lower = round(investment_1[8]*(invested_amt),2)
    ci_upper = round(investment_1[9]*(invested_amt),2)
                
else: 
    coin_prompt == ['cardano' 'ADA', 'Cardano']        
    investment_1 = MC_ADA.summarize_cumulative_return()
    ci_lower = round(investment_1[8]*(invested_amt),2)
    ci_upper = round(investment_1[9]*(invested_amt),2)
   
                        
    if answer == 'N':
        print(f"There is a 95% chance that an initial investment of ${invested_amt} in {coin_prompt}(${value})"
      f" over the next 5 years will end within in the range of"
      f" ${ci_lower} and ${ci_upper} compared to the CIX100 crypto benchmark with a 95% range of {ci_lower2} and ${ci_upper2} of a $5000 investment.")
    
    else:
        print(f"There is a 95% chance that an initial investment of ${invested_amt} in {coin_prompt}(${value}) and {select_coin}(${remainder_prompt})"
      f" over the next 5 years will end within in the range of"
      f" ${ci_lower} and ${ci_upper} compared to the CIX100 crypto benchmark with a 95% range of {ci_lower2} and ${ci_upper2} of a $5000 investment")
# Out:
# There is a 95% chance that an initial investment of $4250 in ETH($4250) over the next 5 years will end within in the range of $5290.96 and $27174060.21 compared to the CIX100 crypto benchmark with a 95% range of 61109.33 and $39505202.77 of a $5000 investment.
