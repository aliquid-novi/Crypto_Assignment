# %% [markdown]
# # Welcome to Crypto Advisor!!

# %% [markdown]
# #### Our aim here is to see how well your investment will perform should you invest in the top 3 cryptocurrencies in the market!
# ####

# %%
welcome_name = input("𝖶𝖾𝗅𝖼𝗈𝗆𝖾 𝗍𝗈 𝖢𝗋𝗒𝗉𝗍𝗈 𝖠𝖽𝗏𝗂𝗌𝗈𝗋!𝗐𝗁𝖺𝗍'𝗌 𝗒𝗈𝗎𝗋 𝗇𝖺𝗆𝖾?")
# Out:
# 𝖶𝖾𝗅𝖼𝗈𝗆𝖾 𝗍𝗈 𝖢𝗋𝗒𝗉𝗍𝗈 𝖠𝖽𝗏𝗂𝗌𝗈𝗋!𝗐𝗁𝖺𝗍'𝗌 𝗒𝗈𝗎𝗋 𝗇𝖺𝗆𝖾? Jose

# %%
print("\033[1m"f"𝖧𝖾𝗅𝗅𝗈, {welcome_name}""\033[1m")
# Out:
# 𝖧𝖾𝗅𝗅𝗈, Jose

# %%
investment = 0

while investment < 5000:
    try:
        investment = int(input("How much are you thinking of investment?"))
        if investment < 5000:
            print("I'm sorry you don't have enough to get started, our minimum requirement is $5,000")
        elif investment >= 5000:
            print("Sounds good")
    except:
        investment = int(input("You dont put a number, please put a number"))
        print("Sounds good")
# Out:
# How much are you thinking of investment? 30000
# Sounds good

# %%
coin_prompt = ''
output = 0
output_2 = 0
output_3 = 0
while coin_prompt not in ['bitcoin','Bitcoin', 'BTC','ethereum', 'Ethereum', 'ETH','Cardano', 'cardano', 'ADA']:
    coin_prompt = input("Great, which cryptocurrency would you like to invest in?")
    try:
        if coin_prompt in ['bitcoin','Bitcoin', 'BTC']:
            output = input("Awesome! how much are you looking to invest in Bitcoin?")
            print(output)
        elif coin_prompt in ['ethereum', 'Ethereum', 'ETH']:
            output_2 = input("Awesome! how much are you looking to invest in Ethereum?")
            print(output_2)
        elif coin_prompt in ['Cardano', 'cardano', 'ADA']:
            output_3 = input("Awesome! how much are you looking to invest in Cardano?")
            print(output_3)
        else: 
            print("please go away")
    except:
        print('Choose the currency again:')
# Out:
# Great, which cryptocurrency would you like to invest in? ADA
# Awesome! how much are you looking to invest in Cardano? 30000
# 30000

# %%
value = int(output) | int(output_2) | int(output_3)

# %%
if value == investment: 
    print("Let's see how your savings will perform")
elif value < investment: 
    remainder_prompt = int((investment) - int(value))
    answer = str(input(f"You'll have a remainder of {remainder_prompt}, are you think of investing this in another coin? Y/N"))
else:
    print(f"The maximum you can invest is {investment}, let's see how this will perform")
# Out:
# Let's see how your savings will perform

# %%
if answer == 'Y':
    select_coin = input("Which of coin?")
    remainder_value = print(f"Okay, {remainder_prompt} has been put into {select_coin}.")
else:
    answer == 'N'
    print(f"No worries, let's move on.")

#total invested amt in code below

if answer == 'N':
    invested_amt = value
else:
    invested_amt = investment
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-29868d37f66a> in <module>
# ----> 1 if answer == 'Y':
#       2     select_coin = input("Which of coin?")
#       3     remainder_value = print(f"Okay, {remainder_prompt} has been put into {select_coin}.")
#       4 else:
#       5     answer == 'N'
#
# NameError: name 'answer' is not defined

# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv
from MCForecastTools import MCSimulation
import cryptocompare as cryptoapi 

# %matplotlib inline

# %%
btc_url = "https://min-api.cryptocompare.com/data/v2/histoday?fsym=BTC&tsym=USD&limit=1095"
eth_url = "https://min-api.cryptocompare.com/data/v2/histoday?fsym=ETH&tsym=USD&limit=1095"
ada_url = "https://min-api.cryptocompare.com/data/v2/histoday?fsym=ADA&tsym=USD&limit=1095"
btc_data = requests.get(btc_url).json()
eth_data = requests.get(eth_url).json() 
ada_data = requests.get(ada_url).json()

# %%
import json

# %%
btc_s0= []
date = []
for price in range(0,len(btc_data['Data']['Data'])):
    temp= btc_data['Data']['Data'][price]['close']
    temp_date = btc_data['Data']['Data'][price]['time']
    btc_s0.append(temp)
    date.append(temp_date)

# %%
eth_s0= []
date = []
for price in range(0,len(eth_data['Data']['Data'])):
    temp= eth_data['Data']['Data'][price]['close']
    temp_date = eth_data['Data']['Data'][price]['time']
    eth_s0.append(temp)
    date.append(temp_date)

# %%
ada_s0= []
date = []
for price in range(0,len(ada_data['Data']['Data'])):
    temp= ada_data['Data']['Data'][price]['close']
    temp_date = ada_data['Data']['Data'][price]['time']
    ada_s0.append(temp)
    date.append(temp_date)

# %%
import datetime

# %%
conv_date = []
for date_converted in date:
    date_con = datetime.datetime.fromtimestamp(
        int(date_converted)
    ).strftime('%Y-%m-%d %H:%M:%S')
    print(date_con)
    conv_date.append(date_con)
# Out:
# 2018-11-26 11:00:00
# 2018-11-27 11:00:00
# 2018-11-28 11:00:00
# 2018-11-29 11:00:00
# 2018-11-30 11:00:00
# 2018-12-01 11:00:00
# 2018-12-02 11:00:00
# 2018-12-03 11:00:00
# 2018-12-04 11:00:00
# 2018-12-05 11:00:00
# 2018-12-06 11:00:00
# 2018-12-07 11:00:00
# 2018-12-08 11:00:00
# 2018-12-09 11:00:00
# 2018-12-10 11:00:00
# 2018-12-11 11:00:00
# 2018-12-12 11:00:00
# 2018-12-13 11:00:00
# 2018-12-14 11:00:00
# 2018-12-15 11:00:00
# 2018-12-16 11:00:00
# 2018-12-17 11:00:00
# 2018-12-18 11:00:00
# 2018-12-19 11:00:00
# 2018-12-20 11:00:00
# 2018-12-21 11:00:00
# 2018-12-22 11:00:00
# 2018-12-23 11:00:00
# 2018-12-24 11:00:00
# 2018-12-25 11:00:00
# 2018-12-26 11:00:00
# 2018-12-27 11:00:00
# 2018-12-28 11:00:00
# 2018-12-29 11:00:00
# 2018-12-30 11:00:00
# 2018-12-31 11:00:00
# 2019-01-01 11:00:00
# 2019-01-02 11:00:00
# 2019-01-03 11:00:00
# 2019-01-04 11:00:00
# 2019-01-05 11:00:00
# 2019-01-06 11:00:00
# 2019-01-07 11:00:00
# 2019-01-08 11:00:00
# 2019-01-09 11:00:00
# 2019-01-10 11:00:00
# 2019-01-11 11:00:00
# 2019-01-12 11:00:00
# 2019-01-13 11:00:00
# 2019-01-14 11:00:00
# 2019-01-15 11:00:00
# 2019-01-16 11:00:00
# 2019-01-17 11:00:00
# 2019-01-18 11:00:00
# 2019-01-19 11:00:00
# 2019-01-20 11:00:00
# 2019-01-21 11:00:00
# 2019-01-22 11:00:00
# 2019-01-23 11:00:00
# 2019-01-24 11:00:00
# 2019-01-25 11:00:00
# 2019-01-26 11:00:00
# 2019-01-27 11:00:00
# 2019-01-28 11:00:00
# 2019-01-29 11:00:00
# 2019-01-30 11:00:00
# 2019-01-31 11:00:00
# 2019-02-01 11:00:00
# 2019-02-02 11:00:00
# 2019-02-03 11:00:00
# 2019-02-04 11:00:00
# 2019-02-05 11:00:00
# 2019-02-06 11:00:00
# 2019-02-07 11:00:00
# 2019-02-08 11:00:00
# 2019-02-09 11:00:00
# 2019-02-10 11:00:00
# 2019-02-11 11:00:00
# 2019-02-12 11:00:00
# 2019-02-13 11:00:00
# 2019-02-14 11:00:00
# 2019-02-15 11:00:00
# 2019-02-16 11:00:00
# 2019-02-17 11:00:00
# 2019-02-18 11:00:00
# 2019-02-19 11:00:00
# 2019-02-20 11:00:00
# 2019-02-21 11:00:00
# 2019-02-22 11:00:00
# 2019-02-23 11:00:00
# 2019-02-24 11:00:00
# 2019-02-25 11:00:00
# 2019-02-26 11:00:00
# 2019-02-27 11:00:00
# 2019-02-28 11:00:00
# 2019-03-01 11:00:00
# 2019-03-02 11:00:00
# 2019-03-03 11:00:00
# 2019-03-04 11:00:00
# 2019-03-05 11:00:00
# 2019-03-06 11:00:00
# 2019-03-07 11:00:00
# 2019-03-08 11:00:00
# 2019-03-09 11:00:00
# 2019-03-10 11:00:00
# 2019-03-11 11:00:00
# 2019-03-12 11:00:00
# 2019-03-13 11:00:00
# 2019-03-14 11:00:00
# 2019-03-15 11:00:00
# 2019-03-16 11:00:00
# 2019-03-17 11:00:00
# 2019-03-18 11:00:00
# 2019-03-19 11:00:00
# 2019-03-20 11:00:00
# 2019-03-21 11:00:00
# 2019-03-22 11:00:00
# 2019-03-23 11:00:00
# 2019-03-24 11:00:00
# 2019-03-25 11:00:00
# 2019-03-26 11:00:00
# 2019-03-27 11:00:00
# 2019-03-28 11:00:00
# 2019-03-29 11:00:00
# 2019-03-30 11:00:00
# 2019-03-31 11:00:00
# 2019-04-01 11:00:00
# 2019-04-02 11:00:00
# 2019-04-03 11:00:00
# 2019-04-04 11:00:00
# 2019-04-05 11:00:00
# 2019-04-06 11:00:00
# 2019-04-07 10:00:00
# 2019-04-08 10:00:00
# 2019-04-09 10:00:00
# 2019-04-10 10:00:00
# 2019-04-11 10:00:00
# 2019-04-12 10:00:00
# 2019-04-13 10:00:00
# 2019-04-14 10:00:00
# 2019-04-15 10:00:00
# 2019-04-16 10:00:00
# 2019-04-17 10:00:00
# 2019-04-18 10:00:00
# 2019-04-19 10:00:00
# 2019-04-20 10:00:00
# 2019-04-21 10:00:00
# 2019-04-22 10:00:00
# 2019-04-23 10:00:00
# 2019-04-24 10:00:00
# 2019-04-25 10:00:00
# 2019-04-26 10:00:00
# 2019-04-27 10:00:00
# 2019-04-28 10:00:00
# 2019-04-29 10:00:00
# 2019-04-30 10:00:00
# 2019-05-01 10:00:00
# 2019-05-02 10:00:00
# 2019-05-03 10:00:00
# 2019-05-04 10:00:00
# 2019-05-05 10:00:00
# 2019-05-06 10:00:00
# 2019-05-07 10:00:00
# 2019-05-08 10:00:00
# 2019-05-09 10:00:00
# 2019-05-10 10:00:00
# 2019-05-11 10:00:00
# 2019-05-12 10:00:00
# 2019-05-13 10:00:00
# 2019-05-14 10:00:00
# 2019-05-15 10:00:00
# 2019-05-16 10:00:00
# 2019-05-17 10:00:00
# 2019-05-18 10:00:00
# 2019-05-19 10:00:00
# 2019-05-20 10:00:00
# 2019-05-21 10:00:00
# 2019-05-22 10:00:00
# 2019-05-23 10:00:00
# 2019-05-24 10:00:00
# 2019-05-25 10:00:00
# 2019-05-26 10:00:00
# 2019-05-27 10:00:00
# 2019-05-28 10:00:00
# 2019-05-29 10:00:00
# 2019-05-30 10:00:00
# 2019-05-31 10:00:00
# 2019-06-01 10:00:00
# 2019-06-02 10:00:00
# 2019-06-03 10:00:00
# 2019-06-04 10:00:00
# 2019-06-05 10:00:00
# 2019-06-06 10:00:00
# 2019-06-07 10:00:00
# 2019-06-08 10:00:00
# 2019-06-09 10:00:00
# 2019-06-10 10:00:00
# 2019-06-11 10:00:00
# 2019-06-12 10:00:00
# 2019-06-13 10:00:00
# 2019-06-14 10:00:00
# 2019-06-15 10:00:00
# 2019-06-16 10:00:00
# 2019-06-17 10:00:00
# 2019-06-18 10:00:00
# 2019-06-19 10:00:00
# 2019-06-20 10:00:00
# 2019-06-21 10:00:00
# 2019-06-22 10:00:00
# 2019-06-23 10:00:00
# 2019-06-24 10:00:00
# 2019-06-25 10:00:00
# 2019-06-26 10:00:00
# 2019-06-27 10:00:00
# 2019-06-28 10:00:00
# 2019-06-29 10:00:00
# 2019-06-30 10:00:00
# 2019-07-01 10:00:00
# 2019-07-02 10:00:00
# 2019-07-03 10:00:00
# 2019-07-04 10:00:00
# 2019-07-05 10:00:00
# 2019-07-06 10:00:00
# 2019-07-07 10:00:00
# 2019-07-08 10:00:00
# 2019-07-09 10:00:00
# 2019-07-10 10:00:00
# 2019-07-11 10:00:00
# 2019-07-12 10:00:00
# 2019-07-13 10:00:00
# 2019-07-14 10:00:00
# 2019-07-15 10:00:00
# 2019-07-16 10:00:00
# 2019-07-17 10:00:00
# 2019-07-18 10:00:00
# 2019-07-19 10:00:00
# 2019-07-20 10:00:00
# 2019-07-21 10:00:00
# 2019-07-22 10:00:00
# 2019-07-23 10:00:00
# 2019-07-24 10:00:00
# 2019-07-25 10:00:00
# 2019-07-26 10:00:00
# 2019-07-27 10:00:00
# 2019-07-28 10:00:00
# 2019-07-29 10:00:00
# 2019-07-30 10:00:00
# 2019-07-31 10:00:00
# 2019-08-01 10:00:00
# 2019-08-02 10:00:00
# 2019-08-03 10:00:00
# 2019-08-04 10:00:00
# 2019-08-05 10:00:00
# 2019-08-06 10:00:00
# 2019-08-07 10:00:00
# 2019-08-08 10:00:00
# 2019-08-09 10:00:00
# 2019-08-10 10:00:00
# 2019-08-11 10:00:00
# 2019-08-12 10:00:00
# 2019-08-13 10:00:00
# 2019-08-14 10:00:00
# 2019-08-15 10:00:00
# 2019-08-16 10:00:00
# 2019-08-17 10:00:00
# 2019-08-18 10:00:00
# 2019-08-19 10:00:00
# 2019-08-20 10:00:00
# 2019-08-21 10:00:00
# 2019-08-22 10:00:00
# 2019-08-23 10:00:00
# 2019-08-24 10:00:00
# 2019-08-25 10:00:00
# 2019-08-26 10:00:00
# 2019-08-27 10:00:00
# 2019-08-28 10:00:00
# 2019-08-29 10:00:00
# 2019-08-30 10:00:00
# 2019-08-31 10:00:00
# 2019-09-01 10:00:00
# 2019-09-02 10:00:00
# 2019-09-03 10:00:00
# 2019-09-04 10:00:00
# 2019-09-05 10:00:00
# 2019-09-06 10:00:00
# 2019-09-07 10:00:00
# 2019-09-08 10:00:00
# 2019-09-09 10:00:00
# 2019-09-10 10:00:00
# 2019-09-11 10:00:00
# 2019-09-12 10:00:00
# 2019-09-13 10:00:00
# 2019-09-14 10:00:00
# 2019-09-15 10:00:00
# 2019-09-16 10:00:00
# 2019-09-17 10:00:00
# 2019-09-18 10:00:00
# 2019-09-19 10:00:00
# 2019-09-20 10:00:00
# 2019-09-21 10:00:00
# 2019-09-22 10:00:00
# 2019-09-23 10:00:00
# 2019-09-24 10:00:00
# 2019-09-25 10:00:00
# 2019-09-26 10:00:00
# 2019-09-27 10:00:00
# 2019-09-28 10:00:00
# 2019-09-29 10:00:00
# 2019-09-30 10:00:00
# 2019-10-01 10:00:00
# 2019-10-02 10:00:00
# 2019-10-03 10:00:00
# 2019-10-04 10:00:00
# 2019-10-05 10:00:00
# 2019-10-06 11:00:00
# 2019-10-07 11:00:00
# 2019-10-08 11:00:00
# 2019-10-09 11:00:00
# 2019-10-10 11:00:00
# 2019-10-11 11:00:00
# 2019-10-12 11:00:00
# 2019-10-13 11:00:00
# 2019-10-14 11:00:00
# 2019-10-15 11:00:00
# 2019-10-16 11:00:00
# 2019-10-17 11:00:00
# 2019-10-18 11:00:00
# 2019-10-19 11:00:00
# 2019-10-20 11:00:00
# 2019-10-21 11:00:00
# 2019-10-22 11:00:00
# 2019-10-23 11:00:00
# 2019-10-24 11:00:00
# 2019-10-25 11:00:00
# 2019-10-26 11:00:00
# 2019-10-27 11:00:00
# 2019-10-28 11:00:00
# 2019-10-29 11:00:00
# 2019-10-30 11:00:00
# 2019-10-31 11:00:00
# 2019-11-01 11:00:00
# 2019-11-02 11:00:00
# 2019-11-03 11:00:00
# 2019-11-04 11:00:00
# 2019-11-05 11:00:00
# 2019-11-06 11:00:00
# 2019-11-07 11:00:00
# 2019-11-08 11:00:00
# 2019-11-09 11:00:00
# 2019-11-10 11:00:00
# 2019-11-11 11:00:00
# 2019-11-12 11:00:00
# 2019-11-13 11:00:00
# 2019-11-14 11:00:00
# 2019-11-15 11:00:00
# 2019-11-16 11:00:00
# 2019-11-17 11:00:00
# 2019-11-18 11:00:00
# 2019-11-19 11:00:00
# 2019-11-20 11:00:00
# 2019-11-21 11:00:00
# 2019-11-22 11:00:00
# 2019-11-23 11:00:00
# 2019-11-24 11:00:00
# 2019-11-25 11:00:00
# 2019-11-26 11:00:00
# 2019-11-27 11:00:00
# 2019-11-28 11:00:00
# 2019-11-29 11:00:00
# 2019-11-30 11:00:00
# 2019-12-01 11:00:00
# 2019-12-02 11:00:00
# 2019-12-03 11:00:00
# 2019-12-04 11:00:00
# 2019-12-05 11:00:00
# 2019-12-06 11:00:00
# 2019-12-07 11:00:00
# 2019-12-08 11:00:00
# 2019-12-09 11:00:00
# 2019-12-10 11:00:00
# 2019-12-11 11:00:00
# 2019-12-12 11:00:00
# 2019-12-13 11:00:00
# 2019-12-14 11:00:00
# 2019-12-15 11:00:00
# 2019-12-16 11:00:00
# 2019-12-17 11:00:00
# 2019-12-18 11:00:00
# 2019-12-19 11:00:00
# 2019-12-20 11:00:00
# 2019-12-21 11:00:00
# 2019-12-22 11:00:00
# 2019-12-23 11:00:00
# 2019-12-24 11:00:00
# 2019-12-25 11:00:00
# 2019-12-26 11:00:00
# 2019-12-27 11:00:00
# 2019-12-28 11:00:00
# 2019-12-29 11:00:00
# 2019-12-30 11:00:00
# 2019-12-31 11:00:00
# 2020-01-01 11:00:00
# 2020-01-02 11:00:00
# 2020-01-03 11:00:00
# 2020-01-04 11:00:00
# 2020-01-05 11:00:00
# 2020-01-06 11:00:00
# 2020-01-07 11:00:00
# 2020-01-08 11:00:00
# 2020-01-09 11:00:00
# 2020-01-10 11:00:00
# 2020-01-11 11:00:00
# 2020-01-12 11:00:00
# 2020-01-13 11:00:00
# 2020-01-14 11:00:00
# 2020-01-15 11:00:00
# 2020-01-16 11:00:00
# 2020-01-17 11:00:00
# 2020-01-18 11:00:00
# 2020-01-19 11:00:00
# 2020-01-20 11:00:00
# 2020-01-21 11:00:00
# 2020-01-22 11:00:00
# 2020-01-23 11:00:00
# 2020-01-24 11:00:00
# 2020-01-25 11:00:00
# 2020-01-26 11:00:00
# 2020-01-27 11:00:00
# 2020-01-28 11:00:00
# 2020-01-29 11:00:00
# 2020-01-30 11:00:00
# 2020-01-31 11:00:00
# 2020-02-01 11:00:00
# 2020-02-02 11:00:00
# 2020-02-03 11:00:00
# 2020-02-04 11:00:00
# 2020-02-05 11:00:00
# 2020-02-06 11:00:00
# 2020-02-07 11:00:00
# 2020-02-08 11:00:00
# 2020-02-09 11:00:00
# 2020-02-10 11:00:00
# 2020-02-11 11:00:00
# 2020-02-12 11:00:00
# 2020-02-13 11:00:00
# 2020-02-14 11:00:00
# 2020-02-15 11:00:00
# 2020-02-16 11:00:00
# 2020-02-17 11:00:00
# 2020-02-18 11:00:00
# 2020-02-19 11:00:00
# 2020-02-20 11:00:00
# 2020-02-21 11:00:00
# 2020-02-22 11:00:00
# 2020-02-23 11:00:00
# 2020-02-24 11:00:00
# 2020-02-25 11:00:00
# 2020-02-26 11:00:00
# 2020-02-27 11:00:00
# 2020-02-28 11:00:00
# 2020-02-29 11:00:00
# 2020-03-01 11:00:00
# 2020-03-02 11:00:00
# 2020-03-03 11:00:00
# 2020-03-04 11:00:00
# 2020-03-05 11:00:00
# 2020-03-06 11:00:00
# 2020-03-07 11:00:00
# 2020-03-08 11:00:00
# 2020-03-09 11:00:00
# 2020-03-10 11:00:00
# 2020-03-11 11:00:00
# 2020-03-12 11:00:00
# 2020-03-13 11:00:00
# 2020-03-14 11:00:00
# 2020-03-15 11:00:00
# 2020-03-16 11:00:00
# 2020-03-17 11:00:00
# 2020-03-18 11:00:00
# 2020-03-19 11:00:00
# 2020-03-20 11:00:00
# 2020-03-21 11:00:00
# 2020-03-22 11:00:00
# 2020-03-23 11:00:00
# 2020-03-24 11:00:00
# 2020-03-25 11:00:00
# 2020-03-26 11:00:00
# 2020-03-27 11:00:00
# 2020-03-28 11:00:00
# 2020-03-29 11:00:00
# 2020-03-30 11:00:00
# 2020-03-31 11:00:00
# 2020-04-01 11:00:00
# 2020-04-02 11:00:00
# 2020-04-03 11:00:00
# 2020-04-04 11:00:00
# 2020-04-05 10:00:00
# 2020-04-06 10:00:00
# 2020-04-07 10:00:00
# 2020-04-08 10:00:00
# 2020-04-09 10:00:00
# 2020-04-10 10:00:00
# 2020-04-11 10:00:00
# 2020-04-12 10:00:00
# 2020-04-13 10:00:00
# 2020-04-14 10:00:00
# 2020-04-15 10:00:00
# 2020-04-16 10:00:00
# 2020-04-17 10:00:00
# 2020-04-18 10:00:00
# 2020-04-19 10:00:00
# 2020-04-20 10:00:00
# 2020-04-21 10:00:00
# 2020-04-22 10:00:00
# 2020-04-23 10:00:00
# 2020-04-24 10:00:00
# 2020-04-25 10:00:00
# 2020-04-26 10:00:00
# 2020-04-27 10:00:00
# 2020-04-28 10:00:00
# 2020-04-29 10:00:00
# 2020-04-30 10:00:00
# 2020-05-01 10:00:00
# 2020-05-02 10:00:00
# 2020-05-03 10:00:00
# 2020-05-04 10:00:00
# 2020-05-05 10:00:00
# 2020-05-06 10:00:00
# 2020-05-07 10:00:00
# 2020-05-08 10:00:00
# 2020-05-09 10:00:00
# 2020-05-10 10:00:00
# 2020-05-11 10:00:00
# 2020-05-12 10:00:00
# 2020-05-13 10:00:00
# 2020-05-14 10:00:00
# 2020-05-15 10:00:00
# 2020-05-16 10:00:00
# 2020-05-17 10:00:00
# 2020-05-18 10:00:00
# 2020-05-19 10:00:00
# 2020-05-20 10:00:00
# 2020-05-21 10:00:00
# 2020-05-22 10:00:00
# 2020-05-23 10:00:00
# 2020-05-24 10:00:00
# 2020-05-25 10:00:00
# 2020-05-26 10:00:00
# 2020-05-27 10:00:00
# 2020-05-28 10:00:00
# 2020-05-29 10:00:00
# 2020-05-30 10:00:00
# 2020-05-31 10:00:00
# 2020-06-01 10:00:00
# 2020-06-02 10:00:00
# 2020-06-03 10:00:00
# 2020-06-04 10:00:00
# 2020-06-05 10:00:00
# 2020-06-06 10:00:00
# 2020-06-07 10:00:00
# 2020-06-08 10:00:00
# 2020-06-09 10:00:00
# 2020-06-10 10:00:00
# 2020-06-11 10:00:00
# 2020-06-12 10:00:00
# 2020-06-13 10:00:00
# 2020-06-14 10:00:00
# 2020-06-15 10:00:00
# 2020-06-16 10:00:00
# 2020-06-17 10:00:00
# 2020-06-18 10:00:00
# 2020-06-19 10:00:00
# 2020-06-20 10:00:00
# 2020-06-21 10:00:00
# 2020-06-22 10:00:00
# 2020-06-23 10:00:00
# 2020-06-24 10:00:00
# 2020-06-25 10:00:00
# 2020-06-26 10:00:00
# 2020-06-27 10:00:00
# 2020-06-28 10:00:00
# 2020-06-29 10:00:00
# 2020-06-30 10:00:00
# 2020-07-01 10:00:00
# 2020-07-02 10:00:00
# 2020-07-03 10:00:00
# 2020-07-04 10:00:00
# 2020-07-05 10:00:00
# 2020-07-06 10:00:00
# 2020-07-07 10:00:00
# 2020-07-08 10:00:00
# 2020-07-09 10:00:00
# 2020-07-10 10:00:00
# 2020-07-11 10:00:00
# 2020-07-12 10:00:00
# 2020-07-13 10:00:00
# 2020-07-14 10:00:00
# 2020-07-15 10:00:00
# 2020-07-16 10:00:00
# 2020-07-17 10:00:00
# 2020-07-18 10:00:00
# 2020-07-19 10:00:00
# 2020-07-20 10:00:00
# 2020-07-21 10:00:00
# 2020-07-22 10:00:00
# 2020-07-23 10:00:00
# 2020-07-24 10:00:00
# 2020-07-25 10:00:00
# 2020-07-26 10:00:00
# 2020-07-27 10:00:00
# 2020-07-28 10:00:00
# 2020-07-29 10:00:00
# 2020-07-30 10:00:00
# 2020-07-31 10:00:00
# 2020-08-01 10:00:00
# 2020-08-02 10:00:00
# 2020-08-03 10:00:00
# 2020-08-04 10:00:00
# 2020-08-05 10:00:00
# 2020-08-06 10:00:00
# 2020-08-07 10:00:00
# 2020-08-08 10:00:00
# 2020-08-09 10:00:00
# 2020-08-10 10:00:00
# 2020-08-11 10:00:00
# 2020-08-12 10:00:00
# 2020-08-13 10:00:00
# 2020-08-14 10:00:00
# 2020-08-15 10:00:00
# 2020-08-16 10:00:00
# 2020-08-17 10:00:00
# 2020-08-18 10:00:00
# 2020-08-19 10:00:00
# 2020-08-20 10:00:00
# 2020-08-21 10:00:00
# 2020-08-22 10:00:00
# 2020-08-23 10:00:00
# 2020-08-24 10:00:00
# 2020-08-25 10:00:00
# 2020-08-26 10:00:00
# 2020-08-27 10:00:00
# 2020-08-28 10:00:00
# 2020-08-29 10:00:00
# 2020-08-30 10:00:00
# 2020-08-31 10:00:00
# 2020-09-01 10:00:00
# 2020-09-02 10:00:00
# 2020-09-03 10:00:00
# 2020-09-04 10:00:00
# 2020-09-05 10:00:00
# 2020-09-06 10:00:00
# 2020-09-07 10:00:00
# 2020-09-08 10:00:00
# 2020-09-09 10:00:00
# 2020-09-10 10:00:00
# 2020-09-11 10:00:00
# 2020-09-12 10:00:00
# 2020-09-13 10:00:00
# 2020-09-14 10:00:00
# 2020-09-15 10:00:00
# 2020-09-16 10:00:00
# 2020-09-17 10:00:00
# 2020-09-18 10:00:00
# 2020-09-19 10:00:00
# 2020-09-20 10:00:00
# 2020-09-21 10:00:00
# 2020-09-22 10:00:00
# 2020-09-23 10:00:00
# 2020-09-24 10:00:00
# 2020-09-25 10:00:00
# 2020-09-26 10:00:00
# 2020-09-27 10:00:00
# 2020-09-28 10:00:00
# 2020-09-29 10:00:00
# 2020-09-30 10:00:00
# 2020-10-01 10:00:00
# 2020-10-02 10:00:00
# 2020-10-03 10:00:00
# 2020-10-04 11:00:00
# 2020-10-05 11:00:00
# 2020-10-06 11:00:00
# 2020-10-07 11:00:00
# 2020-10-08 11:00:00
# 2020-10-09 11:00:00
# 2020-10-10 11:00:00
# 2020-10-11 11:00:00
# 2020-10-12 11:00:00
# 2020-10-13 11:00:00
# 2020-10-14 11:00:00
# 2020-10-15 11:00:00
# 2020-10-16 11:00:00
# 2020-10-17 11:00:00
# 2020-10-18 11:00:00
# 2020-10-19 11:00:00
# 2020-10-20 11:00:00
# 2020-10-21 11:00:00
# 2020-10-22 11:00:00
# 2020-10-23 11:00:00
# 2020-10-24 11:00:00
# 2020-10-25 11:00:00
# 2020-10-26 11:00:00
# 2020-10-27 11:00:00
# 2020-10-28 11:00:00
# 2020-10-29 11:00:00
# 2020-10-30 11:00:00
# 2020-10-31 11:00:00
# 2020-11-01 11:00:00
# 2020-11-02 11:00:00
# 2020-11-03 11:00:00
# 2020-11-04 11:00:00
# 2020-11-05 11:00:00
# 2020-11-06 11:00:00
# 2020-11-07 11:00:00
# 2020-11-08 11:00:00
# 2020-11-09 11:00:00
# 2020-11-10 11:00:00
# 2020-11-11 11:00:00
# 2020-11-12 11:00:00
# 2020-11-13 11:00:00
# 2020-11-14 11:00:00
# 2020-11-15 11:00:00
# 2020-11-16 11:00:00
# 2020-11-17 11:00:00
# 2020-11-18 11:00:00
# 2020-11-19 11:00:00
# 2020-11-20 11:00:00
# 2020-11-21 11:00:00
# 2020-11-22 11:00:00
# 2020-11-23 11:00:00
# 2020-11-24 11:00:00
# 2020-11-25 11:00:00
# 2020-11-26 11:00:00
# 2020-11-27 11:00:00
# 2020-11-28 11:00:00
# 2020-11-29 11:00:00
# 2020-11-30 11:00:00
# 2020-12-01 11:00:00
# 2020-12-02 11:00:00
# 2020-12-03 11:00:00
# 2020-12-04 11:00:00
# 2020-12-05 11:00:00
# 2020-12-06 11:00:00
# 2020-12-07 11:00:00
# 2020-12-08 11:00:00
# 2020-12-09 11:00:00
# 2020-12-10 11:00:00
# 2020-12-11 11:00:00
# 2020-12-12 11:00:00
# 2020-12-13 11:00:00
# 2020-12-14 11:00:00
# 2020-12-15 11:00:00
# 2020-12-16 11:00:00
# 2020-12-17 11:00:00
# 2020-12-18 11:00:00
# 2020-12-19 11:00:00
# 2020-12-20 11:00:00
# 2020-12-21 11:00:00
# 2020-12-22 11:00:00
# 2020-12-23 11:00:00
# 2020-12-24 11:00:00
# 2020-12-25 11:00:00
# 2020-12-26 11:00:00
# 2020-12-27 11:00:00
# 2020-12-28 11:00:00
# 2020-12-29 11:00:00
# 2020-12-30 11:00:00
# 2020-12-31 11:00:00
# 2021-01-01 11:00:00
# 2021-01-02 11:00:00
# 2021-01-03 11:00:00
# 2021-01-04 11:00:00
# 2021-01-05 11:00:00
# 2021-01-06 11:00:00
# 2021-01-07 11:00:00
# 2021-01-08 11:00:00
# 2021-01-09 11:00:00
# 2021-01-10 11:00:00
# 2021-01-11 11:00:00
# 2021-01-12 11:00:00
# 2021-01-13 11:00:00
# 2021-01-14 11:00:00
# 2021-01-15 11:00:00
# 2021-01-16 11:00:00
# 2021-01-17 11:00:00
# 2021-01-18 11:00:00
# 2021-01-19 11:00:00
# 2021-01-20 11:00:00
# 2021-01-21 11:00:00
# 2021-01-22 11:00:00
# 2021-01-23 11:00:00
# 2021-01-24 11:00:00
# 2021-01-25 11:00:00
# 2021-01-26 11:00:00
# 2021-01-27 11:00:00
# 2021-01-28 11:00:00
# 2021-01-29 11:00:00
# 2021-01-30 11:00:00
# 2021-01-31 11:00:00
# 2021-02-01 11:00:00
# 2021-02-02 11:00:00
# 2021-02-03 11:00:00
# 2021-02-04 11:00:00
# 2021-02-05 11:00:00
# 2021-02-06 11:00:00
# 2021-02-07 11:00:00
# 2021-02-08 11:00:00
# 2021-02-09 11:00:00
# 2021-02-10 11:00:00
# 2021-02-11 11:00:00
# 2021-02-12 11:00:00
# 2021-02-13 11:00:00
# 2021-02-14 11:00:00
# 2021-02-15 11:00:00
# 2021-02-16 11:00:00
# 2021-02-17 11:00:00
# 2021-02-18 11:00:00
# 2021-02-19 11:00:00
# 2021-02-20 11:00:00
# 2021-02-21 11:00:00
# 2021-02-22 11:00:00
# 2021-02-23 11:00:00
# 2021-02-24 11:00:00
# 2021-02-25 11:00:00
# 2021-02-26 11:00:00
# 2021-02-27 11:00:00
# 2021-02-28 11:00:00
# 2021-03-01 11:00:00
# 2021-03-02 11:00:00
# 2021-03-03 11:00:00
# 2021-03-04 11:00:00
# 2021-03-05 11:00:00
# 2021-03-06 11:00:00
# 2021-03-07 11:00:00
# 2021-03-08 11:00:00
# 2021-03-09 11:00:00
# 2021-03-10 11:00:00
# 2021-03-11 11:00:00
# 2021-03-12 11:00:00
# 2021-03-13 11:00:00
# 2021-03-14 11:00:00
# 2021-03-15 11:00:00
# 2021-03-16 11:00:00
# 2021-03-17 11:00:00
# 2021-03-18 11:00:00
# 2021-03-19 11:00:00
# 2021-03-20 11:00:00
# 2021-03-21 11:00:00
# 2021-03-22 11:00:00
# 2021-03-23 11:00:00
# 2021-03-24 11:00:00
# 2021-03-25 11:00:00
# 2021-03-26 11:00:00
# 2021-03-27 11:00:00
# 2021-03-28 11:00:00
# 2021-03-29 11:00:00
# 2021-03-30 11:00:00
# 2021-03-31 11:00:00
# 2021-04-01 11:00:00
# 2021-04-02 11:00:00
# 2021-04-03 11:00:00
# 2021-04-04 10:00:00
# 2021-04-05 10:00:00
# 2021-04-06 10:00:00
# 2021-04-07 10:00:00
# 2021-04-08 10:00:00
# 2021-04-09 10:00:00
# 2021-04-10 10:00:00
# 2021-04-11 10:00:00
# 2021-04-12 10:00:00
# 2021-04-13 10:00:00
# 2021-04-14 10:00:00
# 2021-04-15 10:00:00
# 2021-04-16 10:00:00
# 2021-04-17 10:00:00
# 2021-04-18 10:00:00
# 2021-04-19 10:00:00
# 2021-04-20 10:00:00
# 2021-04-21 10:00:00
# 2021-04-22 10:00:00
# 2021-04-23 10:00:00
# 2021-04-24 10:00:00
# 2021-04-25 10:00:00
# 2021-04-26 10:00:00
# 2021-04-27 10:00:00
# 2021-04-28 10:00:00
# 2021-04-29 10:00:00
# 2021-04-30 10:00:00
# 2021-05-01 10:00:00
# 2021-05-02 10:00:00
# 2021-05-03 10:00:00
# 2021-05-04 10:00:00
# 2021-05-05 10:00:00
# 2021-05-06 10:00:00
# 2021-05-07 10:00:00
# 2021-05-08 10:00:00
# 2021-05-09 10:00:00
# 2021-05-10 10:00:00
# 2021-05-11 10:00:00
# 2021-05-12 10:00:00
# 2021-05-13 10:00:00
# 2021-05-14 10:00:00
# 2021-05-15 10:00:00
# 2021-05-16 10:00:00
# 2021-05-17 10:00:00
# 2021-05-18 10:00:00
# 2021-05-19 10:00:00
# 2021-05-20 10:00:00
# 2021-05-21 10:00:00
# 2021-05-22 10:00:00
# 2021-05-23 10:00:00
# 2021-05-24 10:00:00
# 2021-05-25 10:00:00
# 2021-05-26 10:00:00
# 2021-05-27 10:00:00
# 2021-05-28 10:00:00
# 2021-05-29 10:00:00
# 2021-05-30 10:00:00
# 2021-05-31 10:00:00
# 2021-06-01 10:00:00
# 2021-06-02 10:00:00
# 2021-06-03 10:00:00
# 2021-06-04 10:00:00
# 2021-06-05 10:00:00
# 2021-06-06 10:00:00
# 2021-06-07 10:00:00
# 2021-06-08 10:00:00
# 2021-06-09 10:00:00
# 2021-06-10 10:00:00
# 2021-06-11 10:00:00
# 2021-06-12 10:00:00
# 2021-06-13 10:00:00
# 2021-06-14 10:00:00
# 2021-06-15 10:00:00
# 2021-06-16 10:00:00
# 2021-06-17 10:00:00
# 2021-06-18 10:00:00
# 2021-06-19 10:00:00
# 2021-06-20 10:00:00
# 2021-06-21 10:00:00
# 2021-06-22 10:00:00
# 2021-06-23 10:00:00
# 2021-06-24 10:00:00
# 2021-06-25 10:00:00
# 2021-06-26 10:00:00
# 2021-06-27 10:00:00
# 2021-06-28 10:00:00
# 2021-06-29 10:00:00
# 2021-06-30 10:00:00
# 2021-07-01 10:00:00
# 2021-07-02 10:00:00
# 2021-07-03 10:00:00
# 2021-07-04 10:00:00
# 2021-07-05 10:00:00
# 2021-07-06 10:00:00
# 2021-07-07 10:00:00
# 2021-07-08 10:00:00
# 2021-07-09 10:00:00
# 2021-07-10 10:00:00
# 2021-07-11 10:00:00
# 2021-07-12 10:00:00
# 2021-07-13 10:00:00
# 2021-07-14 10:00:00
# 2021-07-15 10:00:00
# 2021-07-16 10:00:00
# 2021-07-17 10:00:00
# 2021-07-18 10:00:00
# 2021-07-19 10:00:00
# 2021-07-20 10:00:00
# 2021-07-21 10:00:00
# 2021-07-22 10:00:00
# 2021-07-23 10:00:00
# 2021-07-24 10:00:00
# 2021-07-25 10:00:00
# 2021-07-26 10:00:00
# 2021-07-27 10:00:00
# 2021-07-28 10:00:00
# 2021-07-29 10:00:00
# 2021-07-30 10:00:00
# 2021-07-31 10:00:00
# 2021-08-01 10:00:00
# 2021-08-02 10:00:00
# 2021-08-03 10:00:00
# 2021-08-04 10:00:00
# 2021-08-05 10:00:00
# 2021-08-06 10:00:00
# 2021-08-07 10:00:00
# 2021-08-08 10:00:00
# 2021-08-09 10:00:00
# 2021-08-10 10:00:00
# 2021-08-11 10:00:00
# 2021-08-12 10:00:00
# 2021-08-13 10:00:00
# 2021-08-14 10:00:00
# 2021-08-15 10:00:00
# 2021-08-16 10:00:00
# 2021-08-17 10:00:00
# 2021-08-18 10:00:00
# 2021-08-19 10:00:00
# 2021-08-20 10:00:00
# 2021-08-21 10:00:00
# 2021-08-22 10:00:00
# 2021-08-23 10:00:00
# 2021-08-24 10:00:00
# 2021-08-25 10:00:00
# 2021-08-26 10:00:00
# 2021-08-27 10:00:00
# 2021-08-28 10:00:00
# 2021-08-29 10:00:00
# 2021-08-30 10:00:00
# 2021-08-31 10:00:00
# 2021-09-01 10:00:00
# 2021-09-02 10:00:00
# 2021-09-03 10:00:00
# 2021-09-04 10:00:00
# 2021-09-05 10:00:00
# 2021-09-06 10:00:00
# 2021-09-07 10:00:00
# 2021-09-08 10:00:00
# 2021-09-09 10:00:00
# 2021-09-10 10:00:00
# 2021-09-11 10:00:00
# 2021-09-12 10:00:00
# 2021-09-13 10:00:00
# 2021-09-14 10:00:00
# 2021-09-15 10:00:00
# 2021-09-16 10:00:00
# 2021-09-17 10:00:00
# 2021-09-18 10:00:00
# 2021-09-19 10:00:00
# 2021-09-20 10:00:00
# 2021-09-21 10:00:00
# 2021-09-22 10:00:00
# 2021-09-23 10:00:00
# 2021-09-24 10:00:00
# 2021-09-25 10:00:00
# 2021-09-26 10:00:00
# 2021-09-27 10:00:00
# 2021-09-28 10:00:00
# 2021-09-29 10:00:00
# 2021-09-30 10:00:00
# 2021-10-01 10:00:00
# 2021-10-02 10:00:00
# 2021-10-03 11:00:00
# 2021-10-04 11:00:00
# 2021-10-05 11:00:00
# 2021-10-06 11:00:00
# 2021-10-07 11:00:00
# 2021-10-08 11:00:00
# 2021-10-09 11:00:00
# 2021-10-10 11:00:00
# 2021-10-11 11:00:00
# 2021-10-12 11:00:00
# 2021-10-13 11:00:00
# 2021-10-14 11:00:00
# 2021-10-15 11:00:00
# 2021-10-16 11:00:00
# 2021-10-17 11:00:00
# 2021-10-18 11:00:00
# 2021-10-19 11:00:00
# 2021-10-20 11:00:00
# 2021-10-21 11:00:00
# 2021-10-22 11:00:00
# 2021-10-23 11:00:00
# 2021-10-24 11:00:00
# 2021-10-25 11:00:00
# 2021-10-26 11:00:00
# 2021-10-27 11:00:00
# 2021-10-28 11:00:00
# 2021-10-29 11:00:00
# 2021-10-30 11:00:00
# 2021-10-31 11:00:00
# 2021-11-01 11:00:00
# 2021-11-02 11:00:00
# 2021-11-03 11:00:00
# 2021-11-04 11:00:00
# 2021-11-05 11:00:00
# 2021-11-06 11:00:00
# 2021-11-07 11:00:00
# 2021-11-08 11:00:00
# 2021-11-09 11:00:00
# 2021-11-10 11:00:00
# 2021-11-11 11:00:00
# 2021-11-12 11:00:00
# 2021-11-13 11:00:00
# 2021-11-14 11:00:00
# 2021-11-15 11:00:00
# 2021-11-16 11:00:00
# 2021-11-17 11:00:00
# 2021-11-18 11:00:00
# 2021-11-19 11:00:00
# 2021-11-20 11:00:00
# 2021-11-21 11:00:00
# 2021-11-22 11:00:00
# 2021-11-23 11:00:00
# 2021-11-24 11:00:00
# 2021-11-25 11:00:00

# %%
list_name_date = conv_date
df_date = pd.DataFrame (list_name_date, columns = ['date'])

# %%
list_name_ada = ada_s0
df_ada = pd.DataFrame (list_name_ada, columns = ['ADA'])

# %%
list_name_eth = eth_s0
df_eth = pd.DataFrame (list_name_eth, columns = ['ETH'])

# %%
list_name_btc = btc_s0
df_btc = pd.DataFrame (list_name_btc, columns = ['BTC'])

# %%
dataset = pd.concat([df_date, df_ada, df_eth, df_btc], axis=1)

# %%
dataset = dataset.set_index('date')

# %% [markdown]
# Gathering Data (Benchmark)

# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
data = Path("Historical_data.csv")

# %%
benchmark_df = pd.read_csv(data, index_col = 'Date', infer_datetime_format=True, parse_dates=True)

# %%
benchmark_df = benchmark_df.sort_values(['Date'], ascending = True)

# %%
a = benchmark_df['Close/Last']

# %%
CIX100_prices = benchmark_df.drop(columns=['Volume', 'Open', 'High', 'Low'])
CIX100_std = CIX100_prices.std
CIX100_std()
# Out:
# Close/Last    2.08323
# dtype: float64

# %%
CIX100_sharpe = (CIX100_prices.mean() * 252) / (CIX100_std() * np.sqrt(252))
CIX100_sharpe
# Out:
# Close/Last    18.059808
# dtype: float64

# %%
t1 = dataset[["BTC","ETH","ADA"]]

# %%
tpct = dataset[["BTC","ETH","ADA"]].pct_change()
tmean = dataset[["BTC","ETH","ADA"]].mean
tstd = dataset[["BTC","ETH","ADA"]].std

# %%
from MCForecastTools import MCSimulation

# %%
CIX100_prices.rename(columns={'Close/Last':"Close"})
CIX100_prices.columns = pd.MultiIndex.from_product([CIX100_prices.columns,['close']])

# %%
num_sims = 1000

MC_CRYPTO = MCSimulation(
    portfolio_data = CIX100_prices,
    num_simulation = num_sims,
    num_trading_days = 252*5
)

# %%
MC_CRYPTO.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# Running Monte Carlo simulation number 500.
# Running Monte Carlo simulation number 510.
# Running Monte Carlo simulation number 520.
# Running Monte Carlo simulation number 530.
# Running Monte Carlo simulation number 540.
# Running Monte Carlo simulation number 550.
# Running Monte Carlo simulation number 560.
# Running Monte Carlo simulation number 570.
# Running Monte Carlo simulation number 580.
# Running Monte Carlo simulation number 590.
# Running Monte Carlo simulation number 600.
# Running Monte Carlo simulation number 610.
# Running Monte Carlo simulation number 620.
# Running Monte Carlo simulation number 630.
# Running Monte Carlo simulation number 640.
# Running Monte Carlo simulation number 650.
# Running Monte Carlo simulation number 660.
# Running Monte Carlo simulation number 670.
# Running Monte Carlo simulation number 680.
# Running Monte Carlo simulation number 690.
# Running Monte Carlo simulation number 700.
# Running Monte Carlo simulation number 710.
# Running Monte Carlo simulation number 720.
# Running Monte Carlo simulation number 730.
# Running Monte Carlo simulation number 740.
# Running Monte Carlo simulation number 750.
# Running Monte Carlo simulation number 760.
# Running Monte Carlo simulation number 770.
# Running Monte Carlo simulation number 780.
# Running Monte Carlo simulation number 790.
# Running Monte Carlo simulation number 800.
# Running Monte Carlo simulation number 810.
# Running Monte Carlo simulation number 820.
# Running Monte Carlo simulation number 830.
# Running Monte Carlo simulation number 840.
# Running Monte Carlo simulation number 850.
# Running Monte Carlo simulation number 860.
# Running Monte Carlo simulation number 870.
# Running Monte Carlo simulation number 880.
# Running Monte Carlo simulation number 890.
# Running Monte Carlo simulation number 900.
# Running Monte Carlo simulation number 910.
# Running Monte Carlo simulation number 920.
# Running Monte Carlo simulation number 930.
# Running Monte Carlo simulation number 940.
# Running Monte Carlo simulation number 950.
# Running Monte Carlo simulation number 960.
# Running Monte Carlo simulation number 970.
# Running Monte Carlo simulation number 980.
# Running Monte Carlo simulation number 990.
#               0           1          2            3           4    \
# 0        1.000000    1.000000   1.000000     1.000000    1.000000
# 1        0.998898    0.986823   1.068793     1.026021    0.928448
# 2        1.006905    0.919870   1.109136     1.022193    0.910571
# 3        1.085863    0.927595   1.200542     1.066850    0.891686
# 4        1.060908    0.895251   1.250169     1.004646    0.942780
# ...           ...         ...        ...          ...         ...
# 1256  2963.457060  397.521476  57.121342  2076.505765  369.977103
# 1257  2832.535373  417.972108  58.279912  2144.039034  382.761714
# 1258  2708.703257  447.833449  58.270939  2097.858438  364.502079
# 1259  2701.781857  440.594853  54.432499  2028.093904  400.365446
# 1260  2888.606067  437.533471  57.579700  2061.496994  403.681772
#
#               5           6           7            8          9    ...  \
# 0        1.000000    1.000000    1.000000     1.000000   1.000000  ...
# 1        1.038400    0.929726    0.932328     1.007041   1.045316  ...
# 2        1.099023    0.941220    0.967601     1.014070   0.994248  ...
# 3        1.130582    1.006100    0.974434     0.989642   0.993711  ...
# 4        1.098975    0.936009    0.921083     1.072263   1.064581  ...
# ...           ...         ...         ...          ...        ...  ...
# 1256  2691.614043  213.267564  344.285614  1043.156876  61.728748  ...
# 1257  2775.090073  214.153511  363.470683  1110.016591  68.881981  ...
# 1258  2521.454765  211.404797  354.433926  1140.736512  71.926261  ...
# 1259  2539.823563  209.013864  364.596257  1205.687806  69.867964  ...
# 1260  2708.714603  205.774465  358.999222  1200.780268  69.925838  ...
#
#            990        991         992         993         994         995  \
# 0     1.000000   1.000000    1.000000    1.000000    1.000000    1.000000
# 1     1.011572   1.022971    0.995331    1.023743    1.044949    0.978684
# 2     1.010746   1.052409    1.040805    0.928799    1.080748    0.927192
# 3     1.088574   1.031841    1.036024    1.002817    1.037655    0.934510
# 4     1.098164   0.880141    0.955512    1.025528    1.014130    0.951816
# ...        ...        ...         ...         ...         ...         ...
# 1256  6.100886  87.188789  725.375386  175.420534  892.366190  795.483166
# 1257  6.134539  90.203829  745.110884  193.048416  961.898519  761.584310
# 1258  6.197113  87.916242  750.248463  211.302730  994.485207  795.132282
# 1259  6.494273  88.921579  718.369509  221.933673  908.639339  806.870645
# 1260  6.570633  90.702561  668.579523  210.905071  922.523735  822.876674
#
#              996        997        998         999
# 0       1.000000   1.000000   1.000000    1.000000
# 1       0.928899   1.067626   0.935007    1.053837
# 2       0.949532   1.140693   0.892482    1.046164
# 3       0.960502   1.219431   0.829518    1.000317
# 4       0.980466   1.322555   0.808226    0.960153
# ...          ...        ...        ...         ...
# 1256  756.771890  32.620616  15.827213  620.437157
# 1257  758.861446  34.523892  16.176516  638.286346
# 1258  730.794316  36.084215  15.779588  664.459981
# 1259  697.739849  34.099371  14.663245  682.128151
# 1260  683.587221  35.208506  15.119334  671.103164
#
# [1261 rows x 1000 columns]

# %%
simulated_returns_data = {
    "mean": list(MC_CRYPTO.simulated_return.mean(axis=1)),
    "median": list(MC_CRYPTO.simulated_return.median(axis=1)),
    "min": list(MC_CRYPTO.simulated_return.min(axis=1)),
    "max": list(MC_CRYPTO.simulated_return.max(axis=1))
}

# Create a DataFrame with the summary statistics
df_simulated_returns = pd.DataFrame(simulated_returns_data)

# Display sample data
df_simulated_returns.head()
# Out:
#        mean    median       min       max
# 0  1.000000  1.000000  1.000000  1.000000
# 1  1.007375  1.007816  0.837154  1.158924
# 2  1.012559  1.012413  0.788621  1.278833
# 3  1.019028  1.017225  0.752458  1.300394
# 4  1.022830  1.020472  0.752848  1.347828

# %%
df_simulated_returns[['mean', 'median']].plot(title="Simulated Cumulative Return Behavior of CIX100 Over the Next Five Years")
# Out:
# <AxesSubplot:title={'center':'Simulated Cumulative Return Behavior of CIX100 Over the Next Five Years'}>

# %%
cumulative_pnl = invested_amt * df_simulated_returns
cumulative_pnl[['mean','median']].plot(title="Simulated Outcomes Behavior of CIX100 Stock Over the Next 5 Years")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-3104f0a05cd6> in <module>
# ----> 1 cumulative_pnl = invested_amt * df_simulated_returns
#       2 cumulative_pnl[['mean','median']].plot(title="Simulated Outcomes Behavior of CIX100 Stock Over the Next Year")
#
# NameError: name 'invested_amt' is not defined

# %%
simulated_returns_data = {
    "mean": list(MC_CRYPTO.simulated_return.mean(axis=1)),
    "median": list(MC_CRYPTO.simulated_return.median(axis=1)),
    "min": list(MC_CRYPTO.simulated_return.min(axis=1)),
    "max": list(MC_CRYPTO.simulated_return.max(axis=1))
}

# %%
investment_1 = MC_CRYPTO.summarize_cumulative_return()
ci_lower = round(investment_1[8]*(invested_amt),2)
ci_upper = round(investment_1[9]*(invested_amt),2)

print(f"There is a 95% chance that an initial investment of ${invested_amt} in {coin_prompt}"
      f" over the next 5 years will end within in the range of"
      f" ${ci_lower} and ${ci_upper}.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-71da5fa5af0a> in <module>
#       1 investment_1 = MC_CRYPTO.summarize_cumulative_return()
# ----> 2 ci_lower = round(investment_1[8]*(invested_amt),2)
#       3 ci_upper = round(investment_1[9]*(invested_amt),2)
#       4
#       5 print(f"There is a 95% chance that an initial investment of ${invested_amt} in {coin_prompt}"
#
# NameError: name 'invested_amt' is not defined

# %%
investment_2 = MC_CRYPTO.summarize_cumulative_return()
ci_lower = round(investment_2[8]*(remainder_prompt),2)
ci_upper = round(investment_2[9]*(remainder_prompt),2)

print(f"There is a 95% chance that an initial investment of ${remainder_prompt} in {select_coin}"
      f" over the next 5 years will end within in the range of"
      f" ${ci_lower} and ${ci_upper}.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-aa65907327ba> in <module>
#       1 investment_2 = MC_CRYPTO.summarize_cumulative_return()
# ----> 2 ci_lower = round(investment_2[8]*(remainder_prompt),2)
#       3 ci_upper = round(investment_2[9]*(remainder_prompt),2)
#       4
#       5 print(f"There is a 95% chance that an initial investment of ${remainder_prompt} in {select_coin}"
#
# NameError: name 'remainder_prompt' is not defined
